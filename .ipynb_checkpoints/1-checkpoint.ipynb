# %%
from fastbook import *

# %%
urls = search_images_ddg("bird photo", max_images=1)
len(urls),urls[0]
# Out:
# (1,
#  'https://get.wallhere.com/photo/birds-animals-nature-photography-branch-wildlife-beak-robins-bird-finch-robin-blackbird-fauna-perching-bird-vertebrate-close-up-cinclidae-european-robin-old-world-flycatcher-brambling-nightingale-emberizidae-wren-ortolan-bunting-81677.jpg')

# %%
dest = Path('bird.jpg')
if not dest.exists(): download_url(urls[0],dest, show_progress=False)

# %%
im = Image.open(dest)
im.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x179>

# %%
searches = 'Forest', 'Bird'
path = Path('bird_or_not')
if not path.exists():
    for o in searches:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_ddg(f'{o} photo')
        download_images(dest, urls=results[:200])
        resize_images(dest, max_size=400, dest=dest)

# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink)
# Out:
# (#0) []
